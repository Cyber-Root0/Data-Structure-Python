# %% [markdown]
# #Vale 2 pontos a lista toda. O exercício 8 vale 1 ponto, o outro um ponto é subdividido entre o restante dos exercícios.

# %% [markdown]
# ### 1. Elabore uma estrutura para representar um produto (código, nome, preço). Aplique 10% de aumento no preço do produto e apresente. Não use função.

# %%
class product:
  id = 0
  name =0
  price = 0
p = product()
price = float(input('Digite o preço do produto: '))
price = price + (10/100*price)
p.price = price
p.id = int(input('Digite o código do produto: '))
p.name = input('Digite o nome do produto: ')
print('\n=======================\n')
print('Cod: ',str(p.id),'\nName: ',p.name,'\nPrice: ',str(p.price))

# %% [markdown]
# ### 2. Elabore uma estrutura para representar um produto (código, nome, preço). Cadastre 5 produtos, use vetor/lista. Aplique 10% de aumento no preço do produto e apresente todos os dados do preço. Não use função.

# %%
class product:
  cod = 0
  name = ""
  price = 0.0
def menu():
  print('Menu do Sistema')
  print('1 - Register new product')
  print('2 - Edit product')
  print('3 - View Product')
  print('4 - Logout')
  op = int(input('Digite a opção desejada: '))
  return op
def cadastrar():
  for i in range(3):
    p = product() #instanciando a classe
def main():
  products = []
  opcao = menu()
  while opcao>=1 and opcao<=3:  
    opcao = menu()
  new_p = product()
  new_p.cod = int(input('Digite o código do produto: '))
  new_p.name = input('Digite o nome do produto: ')
  new_p.price = float(input('Digite o preço do produto'))

# %% [markdown]
# ### 3. Elabore uma estrutura para representar um produto (código, nome, preço). **Crie uma função** para cadastrar 5 produtos. **Crie outra função** para aplicar 10% de aumento no preço do produto e apresente, por meio **de outra função**, todos os dados do produtos cadastrados, após o aumento. Construa uma função para cada opção do menu a seguir:
# Menu do Sistema
# 1. Cadastrar
# 2. Reajustar
# 3. Visualizar
# 4. Sair
#
# Qual opção deseja?

# %%
products = []
def view_product(id_p):
  for i in range(len(products)):
    if products[i].cod == id_p:
      print('\n\n ========== Product ==========')
      print('Cod: ',str(products[i].cod),'\nName: ',products[i].name,'\nPrice: ',str(products[i].price))
      break
def edit_product(id_p): #function edit a product in vector 'products'
  for i in range(len(products)):
    if products[i].cod == id_p:
      products[i].name=input('Digite o novo nome do produto: ')
      products[i].price = float(input('Digite o novo preço: '))
      print('\n\n===========Produto atualizado com sucesso ==========')
      break
def register(): # Function register a new product
    new_p = product()
    new_p.cod = int(input('Digite o código do produto: '))
    new_p.name = input('Digite o nome do produto: ')
    price = float(input('Digite o preço do produto: '))
    price = price + (10/100*price) # Adding a new price + 10%
    new_p.price = price
    return new_p
class product: # product class
  cod = 0
  name = ""
  price = 0.0
def menu():
  print('\n\n============ Menu do Sistema ==========\n\n')
  print('1 - Register new product')
  print('2 - Edit product')
  print('3 - View Product')
  print('4 - Go out')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  opcao = menu()
  while opcao>=1 and opcao<=3:
    if opcao == 1:
      products.append(register())  
    elif opcao ==2:
      edit_product(int(input('Digite o código do produto que quer editar: ')))
    elif opcao ==3:
      view_product(int(input('Digite o codigo do produto que quer visualizar: ')))
    elif opcao ==4:
      break
    opcao=menu()
  print('Programa finalizado!')
main()
# Out:
# ============ Menu do Sistema ==========
#
#
# 1 - Register new product
# 2 - Edit product
# 3 - View Product
# 4 - Go out
#
#
# ============ Menu do Sistema ==========
#
#
# 1 - Register new product
# 2 - Edit product
# 3 - View Product
# 4 - Go out

# %% [markdown]
# ### 4. Uma escola precisa montar o cadastro geral de seus alunos. Este cadastro deverá conter as seguintes informações por aluno: nome completo, data de nascimento, telefone, endereço e série atual. Levando em conta que esta escola possui no máximo 500 alunos, como você faria para estruturar estas informações num sistema de gerenciamento para a escola? Implemente utilizando estrutura. Também **use a criação de funções para cada operação**. Use o menu a seguir:
# Menu de opções:
# 1. Cadastrar alunos
# 2. Consulta por nome
# 3. Visualizar todos os dados
# 4. Sair

# %%
alunos = []
def view_all():
  for i in range(len(alunos)):
    print('\nName: ',str(alunos[i].name),'\nSerie: ',alunos[i].serie,'\nAdress: ',str(alunos[i].adress),'\nTelefone: ',alunos[i].telefone,'\nData de Nascimento: ',str(alunos[i].nasc_dia),'/',str(alunos[i].nasc_mes),'/',str(alunos[i].nasc_ano))
    print('\n ================== \n')
def view_student(name):
  for i in range(len(alunos)):
    if name in alunos[i].name:
      print('\n\n ========== Student ==========')
      print('Name: ',str(alunos[i].name),'\nSerie: ',alunos[i].serie,'\nAdress: ',str(alunos[i].adress),'\nTelefone: ',alunos[i].telefone,'\nData de Nascimento: ',str(alunos[i].nasc_dia),'/',str(alunos[i].nasc_mes),'/',str(alunos[i].nasc_ano))                                                      
      break
def register(): # Function register a new student
    new_a = student()
    new_a.name = input('Digite o nome do Aluno: ')
    new_a.nasc_dia = int(input('Digite o dia do nascimento: '))
    new_a.nasc_mes = int(input('Digite o mes do nascimento: '))
    new_a.nasc_ano = int(input('Digite o ano do nascimento: '))
    new_a.telefone = input('Digite o telefone do aluno: ')
    new_a.adress = input('Digite o endereço do aluno: ')
    new_a.serie = int(input('Digite a serie do aluno: '))    
    return new_a
class student: # product class
  name = ""
  nasc_dia = 0
  nasc_mes = 0
  nasc_ano = 0
  telefone = ""
  adress = ""
  serie = 0
def menu():
  print('\n\n============ Menu Student ==========\n\n')
  print('1 - Register new student')
  print('2 - see Student by name')
  print('3 - see all students')
  print('4 - Go out')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  opcao = menu()
  while opcao>=1 and opcao<=3:
    if opcao == 1:
      if len(alunos)==500:
        print('Limite de apenas 500 alunos no sistema! ')
      else:
        alunos.append(register())  
    elif opcao ==2:
      view_student(input('Digite o nome do aluno que quer visualizar:  '))
    elif opcao ==3:
      view_all()
    elif opcao ==4:
      break
    opcao=menu()
  print('Programa finalizado!')
main()

# %% [markdown]
# ### 5. Faça um programa que realize o cadastro de contas bancarias com as seguintes informações: numero da conta, nome do titular e saldo. O banco permitirá o cadastramento de 15 contas. **Crie uma função para cada opção do menu** a seguir. Utilize a estrutura na passagem de parâmetro:
# Menu de opções:
# 1. Cadastrar contas
# 2. Visualizar todas as contas
# 3. Consultar por nome
# 4. Alterar nome e/ou saldo de um número de conta
# 5. Excluir a conta com menor saldo
# 6. Sair
#
# Observação:
#
# * No item de menu 4. Alterar nome e/ou saldo de um número de conta, entenda que apenas pode ser alterado o nome e o saldo depois que você pesquisar pelo número da conta.
# * No item 5 do menu, encontre o menor saldo dentre todos cadastrados, **depois exclua esta ÚNICA conta.**. O assunto de excluir algo de um vetor foi dado na disciplina de Algoritmo.

# %%
contas = []
class account:
  id = 0
  name = ""
  value = 0
def deletes():
  i_d = -1
  menor = 999999999999999
  for x in range(len(contas)):
    if (x==0):
      menor = contas[x].value
    if contas[x].value < menor:
      i_d = x
      menor = contas[x].value
  contas.pop(i_d)
def edi_account(id):
  for i in range(len(contas)):
    if id == contas[i].id:
      contas[i].name=input('Digite o novo nome: ')
      contas[i].value = float(input('Digite o novo saldo: '))
      break
def view_account(name):
  for i in range(len(contas)):
    if name in contas[i].name:
      print('\nNumero da Conta: ',str(contas[i].id),'\nTitular: ',contas[i].name,'\nSaldo: ',str(contas[i].value))
      break
def view_all_accounts():
  for i in range(len(contas)):
    print('\nNumero da Conta: ',str(contas[i].id),'\nTitular: ',contas[i].name,'\nSaldo: ',str(contas[i].value))
def register():
  conta = account()
  conta.id = int(input('Digite o numero da conta: '))
  conta.name=input('Digite o nome do titular da conta: ')
  conta.value = float(input('Digite o saldo da conta: '))
  return conta
def menu():
  print('\n\n============ Menu Student ==========\n\n')
  print('1 - Register new account')
  print('2 - see all accounts')
  print('3 - see account by name')
  print('4 - change name and/or value for identication account')
  print('5 - delete account with lower balance')
  print('6 - Go out')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  opcao = menu()
  while opcao>=1 and opcao<=6:
    if opcao == 1:
      if len(contas)<=14:
        contas.append(register()) 
      else:
        print('Limite de apenas 15 contas no sistema! ')
    elif opcao ==2:
      view_all_accounts()
    elif opcao ==3:
      view_account(input('Digite o nome do titular: '))
    elif opcao ==4:
      edi_account(int(input('Digite o numero da conta: ')))
    elif opcao ==5:
      deletes()
    elif opcao ==6:
      break
    opcao = menu()
  print('Programa finalizado!')
main()

# %% [markdown]
# ### 6. Elabore uma estrutura para representar um Funcionario (código, nome, endereço, salário). Para o membro endereço deve-se criar outra estrutura Endereço (logradouro, número, bairro, cidade). **Utilize aninhamento de estruturas** para resolver este desenvolvimento. Construa uma função para cada opçao do menu a seguir:
#
# Menu de opções:
# 1. Cadastrar funcionários
# 2. Visualizar todos os dados
# 3. Sair

# %%
adress = []
users = []
class user:
  id = 0
  name = ''
  salary = 0
class adres:
  log = ''
  number = 0
  bairro = ''
  city = ''
def register():
  print('------------ Dados Pessoais ------------')
  new_u = user()
  new_u.id = int(input('Digite o código do funcionario: '))
  new_u.name = input('Digite o nome do funcionário: ')
  new_u.salarty = float(input('Digite o salario do funcionario: '))
  print('======== Endereço ==========\n')
  new_a = adres()
  new_a.log = input('Digite o endereço: ')
  new_a.bairro = input('Digite o bairro: ')
  new_a.number = int(input('Digite o numero da casa: '))
  new_a.city = input('Qual a cidade? : ')
  adress.append(new_a)
  users.append(new_u)
def view():
  for x in range(len(users)):
    print('------------ Visualização -------------')
    print('Nome: ',users[x].name,'\nCod: ',str(users[x].id),'\nSalario: ',str(users[x].salary) )
    print('\n ---------- Endereço -------------')
    print('R. ',adress[x].log,'\nBairro: ',adress[x].bairro,'\nNumero: ',str(adress[x].number),'\nCidade: ',adress[x].city)
def menu():
  print('\n\n============ Menu ==========\n\n')
  print('1 - Cadastrar novos funcionarios')
  print('2 - Visualizar todos os dados')
  print('3 - Sair')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  opcao = menu()
  while opcao>=1 and opcao<=3:
    if opcao == 1:
      register()
    elif opcao ==2:
      view()
    elif opcao ==3:
      break
    opcao=menu()
  print('Programa finalizado!')
main()

# %% [markdown]
# ### 7. Elabore uma estrutura para representar um Produto (código, nome, data_fabricacao, data_validade, preço). Para o membro data_fabricacao e data_validade, deve-se criar outra estrutura Data (dia, mês, ano). **Utilize aninhamento de estruturas** para resolver este desenvolvimento. Construa uma função para cada opçao do menu a seguir:
#
# Menu de opções:
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair

# %%
produtos = []
class data:
  dia = 0
  mes = 0
  ano = 0
  fab = []
  val = []
class produto:
  cod = 0
  nome = ''
  preco = 0
def register():
  p = produto()
  data_f = data()
  data_v = data()
  p.cod = int(input('Digit o codigo do produto: '))
  p.nome = input('Digite o nome do produto: ')
  p.preco = float(input('Digite o preço do produto: '))
  data_f.dia = int(input('Digite o dia da fabricação: '))
  data_f.mes = int(input('Digite o mes da Fabricação: '))
  data_f.ano = int(input('Digite o ano da Fabricação: '))
  data_v.dia = int(input('Digite o dia da Validade: '))
  data_v.mes = int(input('Digite o mes da Validade: '))
  data_v.ano = int(input('Digite o ano da Validade: '))
  p.fab = data_f
  p.val = data_v
  produtos.append(p)
def view():
  print('--------- Exibição dos Produtos ----------')
  for x in range(len(produtos)):
    print('Código: ',str(produtos[x].cod),'\nNome: ',produtos[x].nome,'\nPreço: ',str(produtos[x].preco),'\nData de Fab.: ',str(produtos[x].fab.dia),'/',str(produtos[x].fab.mes),'/',str(produtos[x].fab.ano))
    print('Data Val. :',str(produtos[x].val.dia),'/',str(produtos[x].val.mes),'/',str(produtos[x].val.ano))
def menu():
  print('\n\n============ Menu ==========\n\n')
  print('1 - Cadastrar novos produtos')
  print('2 - Visualizar todos os dados')
  print('3 - Sair')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  opcao = menu()
  while opcao>=1 and opcao<=3:
    if opcao == 1:
      register()
    elif opcao ==2:
      view()
    elif opcao ==3:
      break
    opcao=menu()
  print('Programa finalizado!')
main()

# %% [markdown]
# ### 8. Elabore duas estruturas, como é apresentado a seguir:
#
# CLIENTE |  DOCUMENTOS |
#  -------|--------------
# cod_cli |   num_doc   |
# nome    |   cod_cli   |
# fone    |   dia_venc  |
#         |   dia_pag   |
#         |   valor     |
#         |   juros     |
#
# * Sabe-se que um documento só pode ser cadastrado para um cliente que já exista.
# * Considere que podem existir, no máximo, 15 clientes e 30 documentos. Crie um vetor para clientes e outro para documentos.
#
# * Crie um menu para a realização de cada uma das operações especificadas a seguir:
#
# **** SISTEMA GERENCIADOR DE CLIENTES E DOCUMENTOS ****
#
# 1. Cadastrar clientes
#
# 2. Relatório de clientes
#
# 3. Cadastrar documentos
#
# 4. Relatório de documentos
#
# 5. Excluir clientes sem documentos
#
# 6. Excluir documentos individuais pelo número
#
# 7. Excluir documentos por cliente
#
# 8. Excluir documentos por período
#
# 9. Alterar as informações dos clientes
#
# 10. Mostrar o total de documentos de determinado cliente
#
# 11. Sair
#
# Qual opção deseja?
#
# .................................................................................................
#
# Para cada item do menu, desenvolva uma função.
#
# A seguir são apresentados os detalhes de implementação de cada opção do menu:
#
# 1. Cadastrar clientes — não pode existir mais que um cliente com o mesmo código.
#
# 2. Relatório de clientes - listar todos os clientes cadastrados.
#
# 3. Cadastrar documentos — ao cadastrar um documento, **se o dia de pagamento for maior que o dia de vencimento, calcular o campo ‘juros’ do registro documentos (5% sobre o valor original do documento)**.
#
# 4. Relatório de documentos - listar todos os documentos cadastrados.
#
# 5. Excluir clientes — um cliente só poderá ser excluído se não existir nenhum documento associado a ele.
#
# 6. Excluir documentos individuais — por meio de seu número. Caso o documento não exista, o programa deverá mostrar a mensagem "Documento não encontrado".
#
# 7. Excluir documentos por cliente — o programa deverá informar o código do cliente e excluir todos os seus documentos. Caso o cliente não exista, deverá mostrar a mensagem "Cliente não encontrado".
#
# 8. Excluir documentos por período — o programa deverá informar o dia inicial e o dia final e excluir todos os documentos que possuam data de vencimento nesse período.
#
# 9. Alterar as informações sobre os clientes — **só NÃO altere o código do cliente**.
#
# 10. Mostrar o total de documentos de determinado cliente.

# %%
clientes = []
documentos = []
class cliente:
  cod = 0
  nome = ''
  fone = ''
class documento:
  num = 0
  cod_cli = 0
  dia_venc = 0
  dia_pag = 0
  valor = 0
  juros = 0
def documento_count_id():
  print('\n------------- Total de Documento dos clientes --------------')
  cod = int(input('Digite o codigo do cliente: '))
  if cliente_valid_cod(cod) == True:
    contador = 0
    for x in range(len(documentos)):
      if documentos[x].cod_cli == cod:
        contador = contador +1
    print('\nDocumentos cadastrados: ',str(contador))
  else:
    print('Esse cliente não existe!')

def cliente_alter_id():
  print('\n------------- Atualizar Cadastro dos clientes --------------')
  cod = int(input('Digite o codigo do cliente: '))
  if cliente_valid_cod(cod) == True:
    clientes[cod].nome = input('Digite o novo nome: ')
    clientes[cod].fone = input('Digite o novo numero: ')
    print('Cliente atualizado com sucesso!')
  else:
    print('Esse cliente não existe!')
def documento_delete_data():
  print('\n------------- Excluir Documento por periodo: --------------')
  i = int(input('Digite a data incicial do periodo: '))
  f = int(input('Digite a data final do periodo'))
  z = False
  for x in range(len(documentos)):
    if documentos[x].dia_venc >= i and documentos[x].dia_venc <= f:
      documentos.pop(x)
      z = True
      print('Documento Excluido....')
  if z == False:
    print('Nenhum documento excluido!')
def documento_delete_id():
  print('\n------------- Excluir documento pelo codigo: --------------')
  id = int(input('Digite o codigo do documento: '))
  s = False
  for x in range(len(documentos)):
    if documentos[x].num == id:
      documentos.pop(x)
      print('Documento Excluido!')
      s = True
      break
  if s == False:
    print('Documento não encontrado!')
def cliente_delete_nodoc():
  print('\n------------- Excluir clientes que não tem documento......')
  for x in range(len(clientes)):
    e = False
    for y in range(len(documentos)):
      if clientes[x].cod == documentos[y].cod_cli:
        e = True
        break
    if e == False:
      clientes.pop(x)
def cliente_valid_cod(cod):
  t = False
  for x in range(len(clientes)):
    if clientes[x].cod == cod:
      t = True
      break
  return t
def cliente_view():
  print('\n------------- Relatorio de Clientes: --------------')
  for x in range(len(clientes)):
    print('Cod: ',str(clientes[x].cod),'\nNome: ',clientes[x].nome,'\nTelefone: ',clientes[x].fone,'\n')
def cliente_register():
  c = cliente()
  print('\n------------- Novo Cliente: --------------')
  cod_c = int(input('Digite o codigo do cliente: '))
  if cliente_valid_cod(cod_c) == False:
    c.cod = cod_c
    c.nome = input('Digite o nome do cliente: ')
    c.fone = input('Digite o telefone do cliente: ')
    clientes.append(c)
  else:
    print('Não pode existir mais de 1 cliente, com o mesmo código.')
def documento_register():
  print('\n------------- Novo Documento: --------------')
  d = documento()
  c = int(input('Digite o codigo do cliente: '))
  if cliente_valid_cod(c) == False:
    print('Documento não cadastrado, não existe nenhum cliente com esse codigo')
  else:
    d.cod_cli = c
    d.num = int(input('Digite o numero do documento: '))
    d.valor = float(input('Digite o valor do documento: '))
    d.dia_venc = int(input('Digite o dia do vencimento: '))
    d.dia_pag = int(input('Digite o dia do pagamento: '))
    if d.dia_pag > d.dia_venc :
      d.juros = 5/100*d.valor
    documentos.append(d)
    print('------- Documento cadastrado --------')
def documento_view():
  print('\n------------- Relatorio de Documentos: --------------')
  for x in range(len(documentos)):
    print('Numero: ',str(documentos[x].num),'\nCod Cliente: ',str(documentos[x].cod_cli),'\nVencimento: ',str(documentos[x].dia_venc),'\nPagamento: ',str(documentos[x].dia_pag))
    print('Valor: ','R$',str(documentos[x].valor),'\nJuros: ','R$',str(documentos[x].juros))
def documento_delete_codcli():
  print('\n------------- Excluir documento pelo código do cliente: --------------')
  cod = int(input('Digite o codigo do cliente: '))
  if cliente_valid_cod(cod) == False:
    print('Cliente não encontrado!')
    return 'a'
  s = False
  for x in range(len(documentos)):
    if documentos[x].cod_cli == cod:
      documentos.pop(x)
      s = True
  if s == True:
    print('Documentos excluidos com sucesso!')
def menu():
  print('\n\n============ Menu ==========\n\n')
  print('1 - Cadastrar clientes')
  print('2 - Relatórios de clientes')
  print('3 - Cadastrar documentos')
  print('4 - Relatórios de documentos')
  print('5 - Excluir clientes sem documento')
  print('6 - Excluir clientes individuais pelo numero')
  print('7 - Excluir documentos por cliente')
  print('8 - Excluir documentos por periodo')
  print('9 - Alterar as informações dos clientes')
  print('10 - Total de documento por clientes')
  print('11 - Sair')
  op = int(input('Digite a opção desejada: '))
  return op
def main():
  functions = [
      'Header :)','cliente_register','cliente_view','documento_register','documento_view','cliente_delete_nodoc','documento_delete_id','documento_delete_codcli','documento_delete_data','cliente_alter_id','documento_count_id'
  ]
  opcao = menu()
  while opcao>=1 and opcao<=11:
    if opcao == 11:
      break
    globals()[functions[opcao]]()
    opcao=menu()
  print('Programa finalizado!')
main()

# %% [markdown]
# ####9. (OPCIONAL A IMPLEMENTAÇÃO) Uma empresa prestadora de serviços armazena informações sobre os serviços prestados. Sabe-se que a empresa pode realizar no máximo três serviços diariamente. É de interesse de sua direção manter um histórico mensal (30 dias) sobre os serviços prestados.
# A empresa realiza quatro tipos de serviços:
#
# 1) pintura;
#
# 2) jardinagem;
#
# 3) faxina e
#
# 4) reforma em geral.
#
# Cada serviço realizado deve ser cadastrado com as seguintes informações: número do serviço, valor do serviço, código do serviço e código do cliente, **numa matriz 30x3 referente a estrutura Servico_prestado**.
#
# Cadastre/digite os quatro tipos de serviços (código e descrição) que a empresa poderá realizar. Para isso, utilize um vetor de quatro posições referente a **estrutura Tipo_servico**.
# O programa deverá mostrar o seguinte menu de opções:
# 1. Cadastrar os tipos de serviços
# 2. Mostrar todos os tipos de serviço
# 3. Cadastrar os serviços prestados
# 4. Mostrar todos os serviços prestados
# 5. Mostrar os serviços prestados em determinado dia
# 6. Mostrar os serviços prestados dentro de um intervalo de valor
# 7. Mostrar um relatório geral (separado por dia), que exiba, inclusive, a descrição do tipo do serviço
# 8. Sair
#
# **Para a opção 1**: deve-se cadastrar os tipos de serviços oferecidos pela empresa, com código e descrição.
#
# **Para a opção 3**: deve-se considerar que deverão ser cadastrados os serviços prestados ao logo do mês. Em cada dia podem ser cadastrados, no máximo, três serviços prestados.
#
# Utilize uma matriz capaz de armazenar em cada posição todas as informações referentes a um serviço prestado (número, valor, código do serviço, código do cliente). **Cada linha representa um dia do mês**. Dessa maneira, considere a matriz com dimensão 30 × 3.
#
# Solicite o dia em que o serviço foi prestado e as demais informações.
# Lembre-se de que a empresa só pode prestar os serviços que já tenham sido cadastrados no vetor de tipo de serviços.
#
# Caso o usuário digite um código de tipo de serviço inválido, o programa deverá mostrar uma mensagem de erro.
#
# Quando o usuário tentar cadastrar mais de três serviços prestados em um mesmo dia, também deverá mostrar uma mensagem de erro.
#
# **Para a opção 5**: o programa deverá receber o dia que se deseja consultar e mostrar os respectivos serviços prestados.
#
# **Para a opção 6**: o programa deverá receber o valor mínimo e o valor máximo e mostrar os serviços prestados que estiverem nesse intervalo.
#
# **Para a opção 7**: o programa deverá mostrar todos os serviços prestados, conforme o exemplo a seguir.
#
#                   DIA 01
#
#
# No do serviço| Valor do serviço R$| Código do serviço| Descrição| Código do cliente
# ---|---|---|---|---
# 100| 200,00| 1| Pintura| 1
# 150| 100,00| 3| Faxina| 5
# 201| 640,00| 4| Reforma em geral| 2
#
#                   DIA 02
#
# No do serviço| Valor do serviço R$| Código do serviço| Descrição| Código do cliente
# ---|---|---|---|---
# 301| 600,00| 4| Reforma em geral| 3
# 280| 352,00| 1| Pintura| 2
# 306| 200,00| 2| Jardinagem| 1
